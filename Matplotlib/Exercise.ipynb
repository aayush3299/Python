# %% [markdown]
# # Matplotlib Exercise
#
# <i>Note: All course material is made by me (Aayush Gandhi) but the exercises are taken as it from a excellent coursera course that i would recommend everyone to try out:</i><br>
# <a href="https://www.udemy.com/course/python-for-data-science-and-machine-learning-bootcamp/">link to course</a><br>
# although the solutions are mine along with the inline explanations.
# ____

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
#answer
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
#answer 
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
plt.title('title')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
#answer 
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
#answer 
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.2,0.2])
ax1.plot(x,y,color='red')
ax2.plot(x,y,'-r')
plt.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-a3ef4b8cc2a1> in <module>
#       5 ax1.plot(x,y,color='red')
#       6 ax2.plot(x,y,'-r')
# ----> 7 plt.pyplot.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'pyplot'

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
#answer
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.4,0.4])

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
#answer
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.4,0.4])
ax1.plot(x,z)
ax1.set_xlabel('X')
ax1.set_ylabel('Z')
ax2.plot(x,y)
ax2.set_xlim(20,22)
ax2.set_ylim(30,50)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('zoom')
# Out:
# Text(0.5, 1.0, 'zoom')

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
#answer
fig,axes=plt.subplots(nrows=1,ncols=2)

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
#answer
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y,color='blue',linestyle="--",linewidth=3)
axes[1].plot(y,z,color="red",linewidth=3)

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
#answer
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(12,2))
axes[0].plot(x,y,color='blue',linewidth=4)
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')

axes[1].plot(y,z,color="red",linewidth=2,linestyle="--")
axes[1].set_xlabel('X')
axes[1].set_ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')
